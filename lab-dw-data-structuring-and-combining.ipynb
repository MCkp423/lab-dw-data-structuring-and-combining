# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd
import numpy as np

df1 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv')
df2 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv')
df3 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv')

# %%
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1['Customer Lifetime Value'].value_counts()
# Out:
# Customer Lifetime Value
# 445811.34%     4
# 251459.20%     4
# 272535.64%     3
# 578018.22%     3
# 684615.03%     3
#               ..
# 245357.08%     1
# 507566.27%     1
# 321497.94%     1
# 1227534.31%    1
# 899704.02%     1
# Name: count, Length: 1027, dtype: int64

# %%
df1['Customer Lifetime Value'].isna().sum()
# Out:
# 2940

# %%
df1['Customer Lifetime Value'] = df1['Customer Lifetime Value'].str.replace('%', ' ')
print(df2['Customer Lifetime Value'])
# Out:
# 0       323912.47%
# 1       462680.11%
# 2       899704.02%
# 3      2580706.30%
# 4       380812.21%
#           ...
# 991     847141.75%
# 992     543121.91%
# 993     568964.41%
# 994     368672.38%
# 995     399258.39%
# Name: Customer Lifetime Value, Length: 996, dtype: object

# %%
df1['Customer Lifetime Value'] = pd.to_numeric(df1['Customer Lifetime Value'], errors='coerce' )

# %%
df1['Customer Lifetime Value'].head()
# Out:
# 0           NaN
# 1     697953.59
# 2    1288743.17
# 3     764586.18
# 4     536307.65
# Name: Customer Lifetime Value, dtype: float64

# %%
df1 = df1.rename(columns={'Customer':'customer', 'ST': 'state', 'GENDER': 'gender',
                       'Education': 'education', 'Customer Lifetime Value': 'customer_lifetime_value',
                       'Income': 'income', 'Monthly Premium Auto': 'monthly_premium_auto', 
                       'Number of Open Complaints': 'number_of_open_complaints', 'Policy Type': 'policy_type', 
                       'Vehicle Class': 'vehicle_class', 'Total Claim Amount': 'total_claim_amount'})
print(df1)
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
df1.isnull()
# Out:
#       customer  state  gender  education  customer_lifetime_value  income  \
# 0        False  False    True      False                     True   False
# 1        False  False   False      False                    False   False
# 2        False  False   False      False                    False   False
# 3        False  False   False      False                    False   False
# 4        False  False   False      False                    False   False
# ...        ...    ...     ...        ...                      ...     ...
# 4003      True   True    True       True                     True    True
# 4004      True   True    True       True                     True    True
# 4005      True   True    True       True                     True    True
# 4006      True   True    True       True                     True    True
# 4007      True   True    True       True                     True    True
#
#       monthly_premium_auto  number_of_open_complaints  policy_type  \
# ...

# %%
df1['gender'].value_counts()
# Out:
# gender
# F         457
# M         413
# Male       39
# female     28
# Femal      17
# Name: count, dtype: int64

# %%
df1['state'].value_counts()
# Out:
# state
# Oregon        320
# California    211
# Arizona       186
# Cali          120
# Nevada         98
# Washington     81
# WA             30
# AZ             25
# Name: count, dtype: int64

# %%
df1['education'].value_counts()
# Out:
# education
# Bachelor                324
# College                 313
# High School or Below    296
# Master                   94
# Doctor                   37
# Bachelors                 7
# Name: count, dtype: int64

# %%
df1['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    576
# Two-Door Car     205
# SUV              199
# Sports Car        57
# Luxury SUV        20
# Luxury Car        14
# Name: count, dtype: int64

# %%
inconsistent_gender_values = df1['gender'].replace({'female': 'F', 'Femal': 'F', 'Male': 'M'})
print (inconsistent_gender_values.value_counts())

inconsistent_state_values = df1['state'].replace({'WA': 'Washington', 'AZ': 'Arizona', 'Cali': 'California'})
print(inconsistent_state_values)

inconsistent_education_values = df1['education'].replace({'Bachelors': 'Bachelor'})
print (inconsistent_education_values)

inconsistent_vehicle_class_values = df1['vehicle_class'].replace({'Sports Car': 'Luxury', 'Luxury SUV': 'Luxury', 'Luxury Car': 'Luxury'})
print (inconsistent_vehicle_class_values)
# Out:
# gender
# F    502
# M    452
# Name: count, dtype: int64
# 0       Washington
# 1          Arizona
# 2           Nevada
# 3       California
# 4       Washington
#            ...
# 4003           NaN
# 4004           NaN
# 4005           NaN
# 4006           NaN
# 4007           NaN
# Name: state, Length: 4008, dtype: object
# 0                     Master
# 1                   Bachelor
# 2                   Bachelor
# 3                   Bachelor
# 4       High School or Below
#                 ...
# 4003                     NaN
# 4004                     NaN
# 4005                     NaN
# 4006                     NaN
# 4007                     NaN
# Name: education, Length: 4008, dtype: object
# 0       Four-Door Car
# 1       Four-Door Car
# 2        Two-Door Car
# 3                 SUV
# 4       Four-Door Car
#             ...
# 4003              NaN
# 4004              NaN
# 4005              NaN
# 4006              NaN
# 4007              NaN
# ...

# %%
df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
df1['number_of_open_complaints'].value_counts()
# Out:
# number_of_open_complaints
# 1/0/00    830
# 1/1/00    138
# 1/2/00     50
# 1/3/00     34
# 1/4/00     13
# 1/5/00      6
# Name: count, dtype: int64

# %%
df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
df1['number_of_open_complaints'] = df1['number_of_open_complaints'].astype(str)
df1['number_of_open_complaints'] = df1['number_of_open_complaints'].str.split('/').str[1]
df1['number_of_open_complaints'] = pd.to_numeric(df1['number_of_open_complaints'], errors='coerce')
df1['number_of_open_complaints'].value_counts()
# Out:
# number_of_open_complaints
# 0.0    830
# 1.0    138
# 2.0     50
# 3.0     34
# 4.0     13
# 5.0      6
# Name: count, dtype: int64

# %%
df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4008 entries, 0 to 4007
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   1071 non-null   object
#  1   state                      1071 non-null   object
#  2   gender                     954 non-null    object
#  3   education                  1071 non-null   object
#  4   customer_lifetime_value    1068 non-null   float64
#  5   income                     1071 non-null   float64
#  6   monthly_premium_auto       1071 non-null   float64
#  7   number_of_open_complaints  1071 non-null   float64
#  8   policy_type                1071 non-null   object
#  9   vehicle_class              1071 non-null   object
#  10  total_claim_amount         1071 non-null   float64
# dtypes: float64(5), object(6)
# memory usage: 344.6+ KB

# %%
df1[['customer','state', 'gender', 'education','policy_type', 'vehicle_class']] = df1[['customer','state', 'gender', 'education','policy_type', 'vehicle_class']].astype(str)

# %%
df1.duplicated().sum()
# Out:
# 2936

# %%
df1.isnull().sum()
# Out:
# customer                        0
# state                           0
# gender                          0
# education                       0
# customer_lifetime_value      2940
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# policy_type                     0
# vehicle_class                   0
# total_claim_amount           2937
# dtype: int64

# %%
df1.dropna(inplace=True)

# %%
df1.isnull().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# policy_type                  0
# vehicle_class                0
# total_claim_amount           0
# dtype: int64

# %%
df1
# Out:
#      customer       state gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# 3                   764586.18      0.0                 106.0
# ...

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df2['Customer Lifetime Value'].value_counts()
# Out:
# Customer Lifetime Value
# 552821.28%     4
# 600521.48%     3
# 538949.95%     3
# 1203662.05%    3
# 871704.98%     3
#               ..
# 728503.10%     1
# 1765196.34%    1
# 1702989.34%    1
# 403931.50%     1
# 399258.39%     1
# Name: count, Length: 950, dtype: int64

# %%
df2['Customer Lifetime Value'].isna().sum()
# Out:
# 4

# %%
df2['Customer Lifetime Value'] = df2['Customer Lifetime Value'].str.replace('%', ' ')
print(df2['Customer Lifetime Value'])
# Out:
# 0       323912.47
# 1       462680.11
# 2       899704.02
# 3      2580706.30
# 4       380812.21
#           ...
# 991     847141.75
# 992     543121.91
# 993     568964.41
# 994     368672.38
# 995     399258.39
# Name: Customer Lifetime Value, Length: 996, dtype: object

# %%
df2['Customer Lifetime Value'] = pd.to_numeric(df2['Customer Lifetime Value'], errors='coerce' )

# %%
df2['Customer Lifetime Value'].head()
# Out:
# 0     323912.47
# 1     462680.11
# 2     899704.02
# 3    2580706.30
# 4     380812.21
# Name: Customer Lifetime Value, dtype: float64

# %%
df2 = df2.rename(columns={'Customer':'customer', 'ST': 'state', 'GENDER': 'gender',
                       'Education': 'education', 'Customer Lifetime Value': 'customer_lifetime_value',
                       'Income': 'income', 'Monthly Premium Auto': 'monthly_premium_auto', 
                       'Number of Open Complaints': 'number_of_open_complaints', 'Policy Type': 'policy_type', 
                       'Vehicle Class': 'vehicle_class', 'Total Claim Amount': 'total_claim_amount'})
print(df2)
# Out:
#     customer       state gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
df2.isnull()
# Out:
#      customer  state  gender  education  customer_lifetime_value  income  \
# 0       False  False   False      False                    False   False
# 1       False  False   False      False                    False   False
# 2       False  False   False      False                    False   False
# 3       False  False   False      False                    False   False
# 4       False  False   False      False                    False   False
# ..        ...    ...     ...        ...                      ...     ...
# 991     False  False   False      False                    False   False
# 992     False  False   False      False                    False   False
# 993     False  False   False      False                    False   False
# 994     False  False   False      False                    False   False
# 995     False  False   False      False                    False   False
#
#      monthly_premium_auto  number_of_open_complaints  total_claim_amount  \
# ...

# %%
df2['gender'].value_counts()
# Out:
# gender
# F         527
# M         461
# female      2
# Male        1
# Name: count, dtype: int64

# %%
df2['state'].value_counts()
# Out:
# state
# Oregon        303
# California    277
# Arizona       142
# Nevada        125
# Washington    100
# AZ             49
# Name: count, dtype: int64

# %%
df2['education'].value_counts()
# Out:
# education
# College                 311
# High School or Below    290
# Bachelor                243
# Master                   86
# Doctor                   49
# Bachelors                17
# Name: count, dtype: int64

# %%
df2['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    519
# Two-Door Car     211
# SUV              174
# Sports Car        55
# Luxury SUV        21
# Luxury Car        16
# Name: count, dtype: int64

# %%
inconsistant_gender_values_counts2 = df2['gender'].replace({'female': 'F', 'Male': 'M'}, inplace=True)
print(inconsistant_gender_values_counts2)

inconsistant_state_values_counts2 = df2['state'].replace({'AZ': 'Arizona'},inplace=True)
print(inconsistant_state_values_counts2)

inconsistant_education_values_counts2 = df2['education'].replace({'Bachelors': 'Bachelor'},inplace=True)
print(inconsistant_education_values_counts2)

inconsistant_vehicle_class_values_counts2 = df2['vehicle_class'].replace({'Sports Car': 'Luxury', 'Luxury SUV': 'Luxury', 'Luxury Car': 'Luxury'},inplace=True)
print(inconsistant_vehicle_class_values_counts2)
# Out:
# None
# None
# None
# None

# %%
df2['number_of_open_complaints'].value_counts()
# Out:
# number_of_open_complaints
# 1/0/00    796
# 1/1/00    109
# 1/2/00     43
# 1/3/00     26
# 1/4/00     16
# 1/5/00      6
# Name: count, dtype: int64

# %%
df2['number_of_open_complaints'] = df2['number_of_open_complaints'].str.split('/').str[1]
df2['number_of_open_complaints'] = pd.to_numeric(df2['number_of_open_complaints'], errors='coerce')
df2['number_of_open_complaints'].value_counts()
# Out:
# number_of_open_complaints
# 0    796
# 1    109
# 2     43
# 3     26
# 4     16
# 5      6
# Name: count, dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 996 entries, 0 to 995
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   996 non-null    object
#  1   state                      996 non-null    object
#  2   gender                     991 non-null    object
#  3   education                  996 non-null    object
#  4   customer_lifetime_value    992 non-null    float64
#  5   income                     996 non-null    int64
#  6   monthly_premium_auto       996 non-null    int64
#  7   number_of_open_complaints  996 non-null    int64
#  8   total_claim_amount         996 non-null    float64
#  9   policy_type                996 non-null    object
#  10  vehicle_class              996 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 85.7+ KB

# %%
df2[['customer','state', 'gender', 'education','policy_type', 'vehicle_class']] = df2[['customer','state', 'gender', 'education','policy_type', 'vehicle_class']].astype(str)

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.isnull().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      4
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# total_claim_amount           0
# policy_type                  0
# vehicle_class                0
# dtype: int64

# %%
df2.dropna(subset=['customer_lifetime_value'], inplace=True)

# %%
df2.isnull().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# total_claim_amount           0
# policy_type                  0
# vehicle_class                0
# dtype: int64

# %%
modes =df2.mode().iloc[0]
df2.fillna(value=modes, inplace=True)
print(df2)
# Out:
#     customer       state gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
df2.duplicated().sum()
# Out:
# 0

# %%
df2.isna().sum()
# Out:
# customer                     0
# state                        0
# gender                       0
# education                    0
# customer_lifetime_value      0
# income                       0
# monthly_premium_auto         0
# number_of_open_complaints    0
# total_claim_amount           0
# policy_type                  0
# vehicle_class                0
# dtype: int64

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df3.isnull().sum()
# Out:
# Customer                     0
# State                        0
# Customer Lifetime Value      0
# Education                    0
# Gender                       0
# Income                       0
# Monthly Premium Auto         0
# Number of Open Complaints    0
# Policy Type                  0
# Total Claim Amount           0
# Vehicle Class                0
# dtype: int64

# %%
df3.duplicated().sum()
# Out:
# 0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7070 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Customer                   7070 non-null   object
#  1   State                      7070 non-null   object
#  2   Customer Lifetime Value    7070 non-null   float64
#  3   Education                  7070 non-null   object
#  4   Gender                     7070 non-null   object
#  5   Income                     7070 non-null   int64
#  6   Monthly Premium Auto       7070 non-null   int64
#  7   Number of Open Complaints  7070 non-null   int64
#  8   Policy Type                7070 non-null   object
#  9   Total Claim Amount         7070 non-null   float64
#  10  Vehicle Class              7070 non-null   object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 607.7+ KB

# %%
df3 = df3.rename(columns={'Customer':'customer', 'State': 'state', 'Gender': 'gender',
                       'Education': 'education', 'Customer Lifetime Value': 'customer_lifetime_value',
                       'Income': 'income', 'Monthly Premium Auto': 'monthly_premium_auto', 
                       'Number of Open Complaints': 'number_of_open_complaints', 'Policy Type': 'policy_type', 
                       'Vehicle Class': 'vehicle_class', 'Total Claim Amount': 'total_claim_amount'})
print(df3)
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
df3['gender'].value_counts()
# Out:
# gender
# F    3576
# M    3494
# Name: count, dtype: int64

# %%
df3['state'].value_counts()
# Out:
# state
# California    2544
# Oregon        1978
# Arizona       1302
# Nevada         659
# Washington     587
# Name: count, dtype: int64

# %%
df3['education'].value_counts()
# Out:
# education
# Bachelor                2152
# College                 2058
# High School or Below    2030
# Master                   572
# Doctor                   258
# Name: count, dtype: int64

# %%
df3['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    3546
# Two-Door Car     1480
# SUV              1401
# Sports Car        371
# Luxury SUV        141
# Luxury Car        131
# Name: count, dtype: int64

# %%
inconsistant_vehicle_class_values_counts3 = df3['vehicle_class'].replace({'Sports Car': 'Luxury', 'Luxury SUV': 'Luxury', 'Luxury Car': 'Luxury'},inplace=True)
print(inconsistant_vehicle_class_values_counts3)
# Out:
# None

# %%
df3['vehicle_class'].value_counts()
# Out:
# vehicle_class
# Four-Door Car    3546
# Two-Door Car     1480
# SUV              1401
# Luxury            643
# Name: count, dtype: int64

# %%
df = pd.concat([df1, df2, df3], ignore_index=True)
display(df)
# Out:
#      customer       state gender             education  \
# 0     QZ44356     Arizona      F              Bachelor
# 1     AI49188      Nevada      F              Bachelor
# 2     WW63253  California      M              Bachelor
# 3     GA49547  Washington      M  High School or Below
# 4     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 9125  LA72316  California      M              Bachelor
# 9126  PK87824  California      F               College
# 9127  TD14365  California      M              Bachelor
# 9128  UP19263  California      M               College
# 9129  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                6.979536e+05      0.0                  94.0
# 1                1.288743e+06  48767.0                 108.0
# 2                7.645862e+05      0.0                 106.0
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
df4 = pd.read_csv('https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv')
display(df4)
# Out:
#        unnamed:_0 customer       state  customer_lifetime_value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877  California              6857.519928       No
#
#        coverage education effective_to_date employmentstatus gender  ...  \
# ...

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
pivot_summary = pd.pivot_table(df4, values='total_claim_amount', index='sales_channel', aggfunc=np.sum)
pivot_summary['Total Revenue'] = np.round(pivot_summary['total_claim_amount'], 2)
print(pivot_summary)
# Out:
#                total_claim_amount  Total Revenue
# sales_channel
# Agent                1.810227e+06     1810226.82
# Branch               1.301204e+06     1301204.00
# Call Center          9.266008e+05      926600.82
# Web                  7.066000e+05      706600.04

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %%
pivot_summary2 = pd.pivot_table(df4, values='customer_lifetime_value', index=['gender','education'], aggfunc=np.mean)
print(pivot_summary2)
# Out:
#                              customer_lifetime_value
# gender education
# F      Bachelor                          7874.269478
#        College                           7748.823325
#        Doctor                            7328.508916
#        High School or Below              8675.220201
#        Master                            8157.053154
# M      Bachelor                          7703.601675
#        College                           8052.459288
#        Doctor                            7415.333638
#        High School or Below              8149.687783
#        Master                            8168.832659

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
